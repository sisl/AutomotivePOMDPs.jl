# %%
using AutomotiveDrivingModels
using AutoViz
using AutomotiveSensors
using AutomotivePOMDPs
using Parameters
using Reel
using StaticArrays
using ProfileView
using Revise

# %%
include("../src/pedestrian_crossing/frenet_pedestrian_emergency_system.jl")
# Out:
# getObjectConfidenceInterval (generic function with 1 method)

# %%
params = CrosswalkParams()
params.obstacles_visible = true

obstacle_1 = ConvexPolygon([VecE2(40, -1.5), VecE2(40, -4.5), VecE2(46.5, -4.5), VecE2(46.5, -1.5)],4)
obstacle_2 = ConvexPolygon([VecE2(40, +4.5), VecE2(40, +7.5), VecE2(46.5, +7.5), VecE2(46.5, +4.5)],4)
params.obstacles = [obstacle_1, obstacle_2]
#params.obstacles = [obstacle_2]

env = CrosswalkEnv(params);



ego_v = 10.0
ped_v = 5.0/3.6
hitpoint = 50             # 50: middle, 100: left corner, 0: right corner
ped_theta = π/2


# fix values
ped_x = 50.0
ped_y_start = -2
ego_y = 0


ped_y_offset_hitpoint = VehicleDef().width * hitpoint / 100 - VehicleDef().width/2
ped_y_end = ped_y_offset_hitpoint
ped_t_collision = (ped_y_end - ped_y_start) / ped_v; 
ego_x = ped_x - ego_v * ped_t_collision - VehicleDef().length/2;


# Car definition
car_initial_state = VehicleState(VecSE2(ego_x, ego_y, 0.), env.roadway.segments[1].lanes[1], env.roadway, ego_v)
car = Vehicle(car_initial_state, VehicleDef(), 1)

# Pedestrian definition using our new Vehicle definition
ped_initial_state = VehicleState(VecSE2(ped_x,ped_y_start,ped_theta), env.crosswalk, env.roadway, ped_v)
ped = Vehicle(ped_initial_state, AutomotivePOMDPs.PEDESTRIAN_DEF, 2)

scene = Scene()
push!(scene, car)
push!(scene, ped)



cam = FitToContentCamera(0.);
timestep = 0.05

pos_noise = 0.1
vel_noise = 0.1
false_positive_rate = 0.05
false_negative_rate = 0.01
rng = MersenneTwister(1);
sensor = AutomotiveSensors.GaussianSensor(AutomotiveSensors.LinearNoise(10, pos_noise, 0.00), 
                 AutomotiveSensors.LinearNoise(10, vel_noise, 0.00), false_positive_rate, false_negative_rate, rng) 



# define a model for each entities present in the scene
models = Dict{Int, DriverModel}()

ego_id = 1
ped_id = 2
models[ego_id] = EmergencySystem(a=LatLonAccel(0.0, 0.0),env=env,sensor=sensor, obstacles=env.obstacles, timestep=timestep)
models[ped_id] = ConstantPedestrian(v_desired=ped_v, dawdling_amp=0.05) # dumb model


nticks = 80
rec = SceneRecord(nticks+1, timestep)
# execute the simulation

risk = Float64[]
collision_rate = Float64[]
ttc = Float64[]
brake_request = Bool[]
prediction = Vector{Array{Float64}}()

sensor_observations = [Vehicle[]]

obs_callback = (ObservationCallback(risk, collision_rate, ttc, brake_request, prediction,sensor_observations),)

tic()
simulate!(rec, scene, env.roadway, models, nticks, obs_callback)
toc()
# Out:
# TTB: 0.885
# standby
# TTB: 0.885
# standby
# TTB: 0.885 collision_rate: 1.0 ttc_m: 1.3689720134952392 ttc_std: 0.04978641180991287Risk: 0.6971802149069114 ttc_min: 1.2693991898754136
#
# standby
# TTB: 0.885 collision_rate: 0.7 ttc_m: 1.3477266423189307 ttc_std: 0.054448679192948025Risk: 0.714384145965861 ttc_min: 1.2388292839330346
#
# standby
# TTB: 0.885 collision_rate: 0.7 ttc_m: 1.2877516093872434 ttc_std: 0.05302827886617544Risk: 0.7489241820557774 ttc_min: 1.1816950516548925
#
# standby
# TTB: 0.885 collision_rate: 0.7 ttc_m: 1.2276840552033998 ttc_std: 0.051607878539402914Risk: 0.7870386399296602 ttc_min: 1.124468298124594
#
# standby
# TTB: 0.885 collision_rate: 0.9 ttc_m: 1.1905778895318222 ttc_std: 0.048637540844627215Risk: 0.8094738197429356 ttc_min: 1.0933028078425677
#
# standby
# TTB: 0.885 collision_rate: 1.0 ttc_m: 1.1408752506550734 ttc_std: 0.04485068994944739Risk: 0.8419159043245255 ttc_min: 1.0511738707561786
#
# standby
# TTB: 0.885 collision_rate: 1.0 ttc_m: 1.0783941983864274 ttc_std: 0.043563110333673764Risk: 0.8927959138117184 ttc_min: 0.9912679777190798
#
# standby
# TTB: 0.885 collision_rate: 0.8 ttc_m: 1.0563113513501088 ttc_std: 0.04723184382896304Risk: 0.9201041218968163 ttc_min: 0.9618476636921827
#
# standby
# TTB: 0.885 collision_rate: 1.0 ttc_m: 0.977957425255562 ttc_std: 0.04141714430738445Risk: 0.9886907887569715 ttc_min: 0.895123136640793
#
# standby
# TTB: 0.885 collision_rate: 0.8 ttc_m: 0.9525890700810726 ttc_std: 0.04513794476250231Risk: 1.0 ttc_min: 0.862313180556068
#
# standby
# brake_request
# brake_delay
# TTB: 0.885 collision_rate: 1.0 ttc_m: 0.8875574706356962 ttc_std: 0.03927117828109509Risk: 1.0 ttc_min: 0.809015114073506
#
# brake_delay
# TTB: 0.885 collision_rate: 1.0 ttc_m: 0.8630189936584763 ttc_std: 0.03884198507583717Risk: 1.0 ttc_min: 0.785335023506802
#
# brake_delay
# TTB: 0.885 collision_rate: 1.0 ttc_m: 0.8025942395031429 ttc_std: 0.037554405460063604Risk: 1.0 ttc_min: 0.7274854285830157
#
# brake_delay
# TTB: 0.885 collision_rate: 1.0 ttc_m: 0.7849091155185668 ttc_std: 0.03712521225480572Risk: 1.0 ttc_min: 0.7106586910089554
#
# brake_delay
# brake_ramp
# TTB: 0.8798259493670886 collision_rate: 1.0 ttc_m: 0.7129029003965368 ttc_std: 0.03737783863511572Risk: 1.0 ttc_min: 0.6381472231263053
#
# brake_ramp
# TTB: 0.8695616883116885 collision_rate: 1.0 ttc_m: 0.6976042885150487 ttc_std: 0.04035530916970097Risk: 1.0 ttc_min: 0.6168936701756468
#
# brake_ramp
# TTB: 0.8543918918918919 collision_rate: 0.7 ttc_m: 0.6807999151069214 ttc_std: 0.049445824431893014Risk: 1.0 ttc_min: 0.5819082662431354
#
# brake_ramp
# brake_max
# TTB: 0.8346428571428571 collision_rate: 0.8 ttc_m: 0.6505553521646804 ttc_std: 0.04912973579592088Risk: 1.0 ttc_min: 0.5522958805728386
#
# brake_max
# TTB: 0.815530303030303 collision_rate: 0.7 ttc_m: 0.6383756566376942 ttc_std: 0.051266410342875046Risk: 1.0 ttc_min: 0.5358428359519442
#
# brake_max
# TTB: 0.7971774193548388 collision_rate: 1.0 ttc_m: 0.6606285239794435 ttc_std: 0.04790349968362027Risk: 1.0 ttc_min: 0.5648215246122029
#
# brake_max
# TTB: 0.7797413793103448 collision_rate: 1.0 ttc_m: 0.6231617992128186 ttc_std: 0.049431217433147746Risk: 1.0 ttc_min: 0.524299364346523
#
# brake_max
# TTB: 0.763425925925926 collision_rate: 1.0 ttc_m: 0.6210061670128 ttc_std: 0.05118526373816074Risk: 1.0 ttc_min: 0.5186356395364785
#
# brake_max
# TTB: 0.7484999999999999 collision_rate: 1.0 ttc_m: 0.6104333223213791 ttc_std: 0.05253324832356325Risk: 1.0 ttc_min: 0.5053668256742526
#
# brake_max
# TTB: 0.7353260869565218 collision_rate: 1.0 ttc_m: 0.6344216557953878 ttc_std: 0.05710135687343831Risk: 1.0 ttc_min: 0.5202189420485112
#
# brake_max
# TTB: 0.7244047619047619 collision_rate: 1.0 ttc_m: 0.5813419896350339 ttc_std: 0.057634516134628194Risk: 1.0 ttc_min: 0.46607295736577753
#
# brake_max
# TTB: 0.7164473684210527 collision_rate: 1.0 ttc_m: 0.6042838871872833 ttc_std: 0.06550843659199061Risk: 1.0 ttc_min: 0.47326701400330207
#
# brake_max
# TTB: 0.7125 collision_rate: 1.0 ttc_m: 0.6605285578550274 ttc_std: 0.06715611329329019Risk: 1.0 ttc_min: 0.526216331268447
#
# brake_max
# TTB: 0.7141666666666667 collision_rate: 1.0 ttc_m: 0.6835755082473971 ttc_std: 0.07382123130435356Risk: 1.0 ttc_min: 0.5359330456386899
#
# brake_max
# TTB: 0.7240384615384616 collision_rate: 1.0 ttc_m: 0.7913402887666533 ttc_std: 0.08649893829043215Risk: 1.0 ttc_min: 0.618342412185789
#
# brake_max
# TTB: 0.7465909090909091
# brake_max
# TTB: 0.7902777777777777
# brake_max
# TTB: 0.8732142857142857
# brake_max
# TTB: 1.0425
# brake_max
# TTB: 1.4708333333333332
# brake_max
# TTB: 3.7125
# brake_max
# TTB: Inf
# brake_max
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf collision_rate: 0.5 ttc_m: Inf ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf collision_rate: 0.4 ttc_m: Inf ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf collision_rate: 0.0 ttc_m: NaN ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf collision_rate: 0.0 ttc_m: NaN ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf collision_rate: 0.0 ttc_m: NaN ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf collision_rate: 0.0 ttc_m: NaN ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf collision_rate: 0.0 ttc_m: NaN ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf
# standby
# TTB: Inf collision_rate: 0.0 ttc_m: NaN ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf collision_rate: 0.0 ttc_m: NaN ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf collision_rate: 0.0 ttc_m: NaN ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf
# standby
# TTB: Inf collision_rate: 0.0 ttc_m: NaN ttc_std: NaNRisk: NaN ttc_min: NaN
#
# standby
# TTB: Inf
# standby
# elapsed time: 1.393311347 seconds
# 1.393311347

# %%
duration, fps, render_hist = animate_record(rec, timestep, env, sensor, sensor_observations, risk, ttc, collision_rate, brake_request, prediction)
film = roll(render_hist, fps = fps, duration = duration)
# Out:
# Reel.Frames{MIME{Symbol("image/png")}}("/tmp/tmpVGCVDA", 0x0000000000000050, 20.0, nothing)
